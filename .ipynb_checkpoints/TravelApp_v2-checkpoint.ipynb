# %% [markdown]
# # Recommender System for Travel App

# %% [markdown]
# ### Let's import some useful libraries

# %%
import torch
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import pickle as pkl
import torch.autograd as autograd
import torch.nn as nn
import os
import math
from collections import Counter
import random
import gensim
import nltk
import random
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import enchant
import matplotlib.pyplot as plt
from nltk import WordNetLemmatizer, word_tokenize, bigrams, ngrams, RegexpTokenizer
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
lemmatize = WordNetLemmatizer()
# %matplotlib inline

# %% [markdown]
# ### Here is the code for the recommender system.  This consists of a deep auto-encoder with a 'fit' and 'predict' method like sklearn.

# %%
class recsys(nn.Module):
    
    
    def __init__(self,ratings=None,users=100,sites=1000,latent_features=10,\
                 dropout=.1,max_iter=10,epochs=4,temperature=1,lr=.01,batch_size=500,\
                 losses=None):
        
        super(recsys,self).__init__()
        
        
        self.users=users
        self.sites=sites
        self.dropout=nn.Dropout(p=dropout)
        self.max_iter=max_iter
        self.lr=lr
        self.batch_size=batch_size
        self.temperature=temperature
        self.ratings=ratings
        self.losses=None
        self.epochs=epochs
        self.linear1=nn.Linear(sites,latent_features)
        self.linear2=nn.Linear(latent_features,latent_features)
        self.linear3=nn.Linear(latent_features,sites)
    
    
    # The input x should have shape (number_of_users,sites)
    # Ratings needs to be a torch tensor of the same shape as x.
    
    
#     def get_mask(self,ratings=None):

#         try: 
#             if ratings==None:
#                 pass
#         except:
#             self.ratings=ratings
            
#         mask=[]
#         for i in range(len(self.ratings)):
#             mask.append([0 if math.isnan(self.ratings[i,j]) else 1 for j in range(len(self.ratings[0]))])
#         return torch.tensor(mask)
       
    
    
    def imputer(self,x=None):
        #Need to make a function which takes in a ratings array and returns
        #an initial best guess.  For now I'll just mask the unkown variables
        #print(type(self.ratings))
        
        try: 
            if x==None:
                ratings=self.ratings
        except:
            ratings=x

                
        ratings[np.isnan(ratings)] = 0
        return torch.tensor(ratings).float()
    

    
    def forward(self,x):
        x=self.imputer(x)
        x=self.linear1(x.float())
        x=torch.tanh(x)
        x=self.linear2(x.float())
        x=self.dropout(x.float())
        x=torch.tanh(x)
        x=self.linear3(x.float())
        return x
    
    
    def custom_loss(self,x,y):
        ct=0
        for i in range(len(x)):
            if (torch.norm(x[i])==0) or (torch.norm(y[i])==0):
                pass
            else:
                ct+=1-(x[i]@y[i])/(torch.norm(x[i])*torch.norm(y[i]))
        return ct/len(x)


    
    def predict(self,x):
        x=self.imputer(x)
        return self.forward(x)
    
    def fit(self,ratings=None):
        
        try: 
            if ratings==None:
                ratings=self.ratings
    
        except:
            pass

        ratings_clean=self.imputer(ratings)
       
        

        loss_function=nn.MSELoss()
    
        


        f= open('data/losses','w+')

        losses=[]

        for i in range(1,self.epochs+1):
            
            optimizer = optim.Adam(self.parameters(),lr=self.lr/i)
            
            print(f'Epoch {i}')
            
            sample_indices=np.random.choice(range(len(ratings_clean)),self.batch_size,replace=False)
            sample=ratings_clean[sample_indices]
            #print(sample_indices)
            
            for _ in range(self.max_iter):
                optimizer.zero_grad()
                out = self.forward(sample)
                #out = self.forward(ratings_clean)
                #loss = loss_function(out,ratings_clean) #This one works!
                loss = self.custom_loss(out,sample)  #This one works
                #loss = self.custom_loss(out,ratings_clean)
                losses.append(float(loss.detach().numpy()))
                f.write(str(loss.detach().numpy())+',')
                loss.backward(retain_graph=True)
                
                optimizer.step()
            self.losses=losses
        f.close()

# %% [markdown]
# ### Now we instantiate an instance of the class recsys.  We also pick some hyperparameters.

# %%
test=recsys(users=100,sites=1000,latent_features=20,dropout=0,epochs=10,max_iter=100,lr=.01,batch_size=50)

# %% [markdown]
# ### We need some data to run this one.  Let's make some data up.

# %%
data=[]
users=100
sites=1000
ranked=30
for j in range(users):
    ra=np.random.choice(range(users),ranked)
    data.append(np.array([10*random.random() if (i in ra) else float('NaN') for i in range(sites)]))
data=np.array(data)

# %% [markdown]
# ### Calling the fit method on this 'data'

# %%
test.fit(data)
# Out:
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Epoch 10

# %% [markdown]
# ### We now have a fit model.  Let's check the loss function.  The losses are stored in the recsys class, so we can just call 'test.losses' to get a list of losses for each iteration.

# %%
plt.scatter(list(range(len(test.losses))),test.losses,s=.3)
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.ylim(0,1)
plt.show()

# %%
test.losses[-1]
# Out:
# 0.1856667846441269

# %% [markdown]
# Here we see that the loss goes up near the beginning of each batch, but the overall trend is towards lower loss.

# %% [markdown]
# ### Now we can make some predictions for a new user....  Since I'm lazy, I'll just make a prediction for one of the previously seen users.  The call looks like this:

# %%
predictions=test.predict(data[2])

# %% [markdown]
# # Making Predictions w/ Real Data

# %% [markdown]
# Now we need to run this with some real data.  Below we have some functions to clean the data.  The data is coming from https://www.tripadvisor.com/ and https://trip.sftravel.com/.

# %%
#Results is a list of user rankings of various attractions in SF.  It is structured as a list of json
# like files of the form [{user1:{attraction1:rating1,attraction2:rating2,attraction3:rating3}, user2:...}]

results=[]
for k in range(100,10000,100):
    with open(f'data/file_{k}.pkl','rb') as f:
        likes=pkl.load(f)
        results.append(likes)
    
# Now we need to combine all the results above into one big dictionary.    
              
res=results[0]
for i in range(1,len(results)):
    res={**res,**results[i]}
    
# We need a dictionary to map trip adviser names to sf_travel site names:  

with open('data/ta_to_sf.pkl','rb') as f:
    ta_to_sf=pkl.load(f)
    
# Finally, we import a dictionary which maps trip-adviser sites to features.
    
with open('data/ta_feature_dct.pkl','rb') as f:
    ta_feature_dct=pkl.load(f)
    
with open('data/loc_info.pkl','rb') as f:
    loc_info=pkl.load(f)

# %%
bla=['Magic Bus', '215 Reviews ']
def remove_reviews(bla):
    return [x for x in bla if 'Reviews' not in x]

loc_info_clean={x: remove_reviews(loc_info[x][1]) for x in loc_info.keys()}

# %%
loc_info_clean
# Out:
# {'Alcatraz Island': ['Nature & Parks',
#   'Sights & Landmarks',
#   'Nature & Wildlife Areas',
#   'National Parks',
#   'Islands',
#   'Historic Sites'],
#  'Golden Gate Bridge': ['Sights & Landmarks', 'Bridges'],
#  'Cable Cars': ['Transportation', 'Tramways'],
#  'Lombard Street': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'Sightseeing Tours in San Francisco': ['Vantigo Tours'],
#  'City Tours in San Francisco': ['Vantigo Tours'],
#  'Pier 39': ['Sights & Landmarks', 'Piers & Boardwalks'],
#  'Walking Tours in San Francisco': ['San Francisco Native Tours'],
#  'Private Tours in San Francisco': ['Vantigo Tours'],
#  'Wine Tours & Tastings in San Francisco': ['Vantigo Tours'],
#  'Boat Tours in San Francisco': ['Bay Voyager'],
#  'Gear Rentals in San Francisco': ["Outspoke'n Bike Rentals"],
#  'Anchor Brewing Company': ['Food & Drink', 'Breweries'],
#  'Food Tours in San Francisco': ['San Francisco Native Tours'],
#  'Cultural Tours in San Francisco': ['Streets of San Francisco Bike Tours'],
#  "Fisherman's Wharf": ['Sights & Landmarks',
#   'Piers & Boardwalks',
#   'Neighborhoods'],
#  'Lands End': ['Outdoor Activities', 'Nature & Parks', 'Hiking Trails'],
#  'AT&T Park': ['Sights & Landmarks', 'Arenas & Stadiums'],
#  'San Francisco Playhouse': ['Concerts & Shows', 'Theaters'],
#  'San Francisco Symphony': ['Concerts & Shows', 'Symphonies'],
#  'San Francisco Bay': ['Nature & Parks', 'Bodies of Water'],
#  'Bus Tours in San Francisco': ['Magic Bus'],
#  'Exploratorium': ['Museums',
#   "Children's Museums",
#   'Science Museums',
#   'Specialty Museums'],
#  'Walt Disney Family Museum': ['Museums', 'Specialty Museums'],
#  'Golden Gate Park': ['Nature & Parks'],
#  'Palace of Fine Arts Theatre': ['Concerts & Shows', 'Theaters'],
#  'Asian Art Museum': ['Museums', 'Art Museums'],
#  'Golden Gate Promenade': ['Outdoor Activities',
#   'Sights & Landmarks',
#   'Jogging Paths & Tracks',
#   'Historic Walking Areas'],
#  'Legion of Honor': ['Museums', 'Art Museums'],
#  'Twin Peaks': ['Sights & Landmarks',
#   'Nature & Parks',
#   'Lookouts',
#   'Mountains',
#   'Neighborhoods',
#   'Historic Walking Areas'],
#  'San Francisco Opera': ['Concerts & Shows', 'Operas'],
#  'San Francisco Museum of Modern Art (SFMOMA)': ['Museums', 'Art Museums'],
#  'Angel Island State Park': ['Nature & Parks', 'State Parks'],
#  'Cable Car Museum': ['Museums', 'Specialty Museums'],
#  '16 Avenue Tiled Steps': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Presidio of San Francisco': ['Nature & Parks',
#   'Sights & Landmarks',
#   'National Parks',
#   'Military Bases & Facilities',
#   'Historic Sites'],
#  'Filbert Steps': ['Sights & Landmarks', 'Historic Walking Areas'],
#  'Scenic 49 Mile Drive': ['Outdoor Activities',
#   'Sights & Landmarks',
#   'Scenic Drives'],
#  'Mission Dolores Park': ['Nature & Parks'],
#  'Historic Streetcars': ['Transportation', 'Tramways'],
#  'Fort Point National Historic Site': ['Sights & Landmarks',
#   'Military Bases & Facilities',
#   'Lighthouses',
#   'Historic Sites'],
#  'San Francisco Botanical Garden': ['Nature & Parks',
#   'Nature & Wildlife Areas',
#   'Gardens'],
#  'Performances in San Francisco': ['The Fillmore'],
#  'California Academy of Sciences': ['Museums', 'Science Museums'],
#  'Baker Beach': ['Outdoor Activities', 'Nature & Parks', 'Beaches'],
#  'Musee Mecanique': ['Museums', 'Specialty Museums'],
#  'San Francisco City Hall': ['Sights & Landmarks',
#   'Government Buildings',
#   'Architectural Buildings'],
#  'Bike Tours in San Francisco': ['Streets of San Francisco Bike Tours'],
#  "Ferry Plaza Farmer's Market": ['Shopping', 'Flea & Street Markets'],
#  'Ferry Building Marketplace': ['Sights & Landmarks',
#   'Shopping',
#   'Points of Interest & Landmarks',
#   'Shopping Malls'],
#  'Wells Fargo History Museum': ['Museums',
#   'Specialty Museums',
#   'History Museums'],
#  'de Young Museum': ['Museums', 'Specialty Museums'],
#  'Crissy Field': ['Nature & Parks'],
#  'Grace Cathedral': ['Sights & Landmarks', 'Sacred & Religious Sites'],
#  "SS Jeremiah O'Brien": ['Museums',
#   'Sights & Landmarks',
#   'Specialty Museums',
#   'Ships',
#   'Historic Sites'],
#  'Night Tours in San Francisco': ['None'],
#  'San Francisco Maritime National Historical Park': ['Sights & Landmarks',
#   'Museums',
#   'Nature & Parks',
#   'Specialty Museums',
#   'National Parks',
#   'Educational sites'],
#  'Gift & Specialty Shops in San Francisco': ['Xela Imports'],
#  'San Francisco Bay Bridge': ['Sights & Landmarks', 'Bridges'],
#  'Orpheum Theatre': ['Concerts & Shows', 'Theaters'],
#  'Mission Dolores': ['Sights & Landmarks',
#   'Missions',
#   'Historic Sites',
#   'Sacred & Religious Sites'],
#  'Segway Tours in San Francisco': ['City Segway Tours San Francisco'],
#  'Historical & Heritage Tours in San Francisco': ['San Francisco Native Tours'],
#  'USS Pampanito': ['Museums',
#   'Sights & Landmarks',
#   'Specialty Museums',
#   'Ships',
#   'Military Museums'],
#  'Sutro Baths': ['Sights & Landmarks', 'Historic Sites'],
#  'Conservatory of Flowers': ['Nature & Parks',
#   'Nature & Wildlife Areas',
#   'Gardens'],
#  'Fort Funston': ['Nature & Parks',
#   'Outdoor Activities',
#   'Beaches',
#   'Nature & Wildlife Areas'],
#  'Beer Tastings & Tours in San Francisco': ['Vantigo Tours'],
#  'Coit Tower': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Observation Decks & Towers',
#   'Monuments & Statues',
#   'Architectural Buildings'],
#  'Eco Tours in San Francisco': ['None'],
#  'San Francisco Maritime National Historical Park Ships at Hyde Street Pier': ['Sights & Landmarks',
#   'Ships'],
#  'Cliff House': ['Sights & Landmarks', 'Historic Sites'],
#  'Japanese Tea Garden': ['Nature & Parks', 'Gardens'],
#  'Movie & TV Tours in San Francisco': ['None'],
#  'The Castro': ['Sights & Landmarks', 'Neighborhoods'],
#  'The Embarcadero': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Piers & Boardwalks',
#   'Neighborhoods',
#   'Historic Walking Areas'],
#  'North Beach': ['Sights & Landmarks', 'Neighborhoods'],
#  'San Francisco Ballet': ['Concerts & Shows', 'Ballets'],
#  'Hiking & Camping Tours in San Francisco': ['Orange Sky Adventures'],
#  'Treasure Island': ['Sights & Landmarks',
#   'Nature & Parks',
#   'Military Bases & Facilities',
#   'Islands'],
#  'Sea Lion Center': ['Nature & Parks',
#   'Zoos & Aquariums',
#   'Nature & Wildlife Areas'],
#  'Climbing Tours in San Francisco': ['None'],
#  'Telegraph Hill': ['Sights & Landmarks',
#   'Lookouts',
#   'Points of Interest & Landmarks',
#   'Observation Decks & Towers',
#   'Historic Walking Areas'],
#  'Nob Hill': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Neighborhoods'],
#  'Little Italy': ['Sights & Landmarks', 'Neighborhoods'],
#  'Barebottle Brewing Company': ['Food & Drink', 'Breweries'],
#  'Yerba Buena Gardens': ['Nature & Parks', 'Gardens'],
#  'Ghirardelli Square': ['Shopping',
#   'Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Shopping Malls'],
#  'Ocean Beach': ['Nature & Parks', 'Outdoor Activities', 'Beaches'],
#  'Helicopter Tours in San Francisco': ['None'],
#  'Russian Hill': ['Sights & Landmarks', 'Neighborhoods'],
#  "St. Mary's Cathedral": ['Sights & Landmarks', 'Sacred & Religious Sites'],
#  'Self-Guided Tours & Rentals in San Francisco': ['Dandyhorse San Francisco Bike Tours & Rental'],
#  'Westfield San Francisco Centre': ['Shopping', 'Shopping Malls'],
#  'Bar, Club & Pub Tours in San Francisco': ['None'],
#  'Bars & Clubs in San Francisco': ['None'],
#  'Union Street': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Neighborhoods'],
#  'Taxis & Shuttles in San Francisco': ['None'],
#  'Day Trips from San Francisco': ['None'],
#  'Marina District': ['Sights & Landmarks', 'Neighborhoods'],
#  'Powell and Market Cable Car Turnaround': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Alamo Square': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'SFJazz Center': ['Concerts & Shows', 'Theaters'],
#  'SS. Peter and Paul Church': ['Sights & Landmarks',
#   'Sacred & Religious Sites'],
#  'Pier 7': ['Sights & Landmarks', 'Piers & Boardwalks'],
#  'Lyon Street Steps': ['Sights & Landmarks', 'Historic Walking Areas'],
#  'Pacific Heights': ['Sights & Landmarks', 'Neighborhoods'],
#  'San Francisco Zoo': ['Outdoor Activities',
#   'Zoos & Aquariums',
#   'Nature & Parks'],
#  'Mission District': ['Sights & Landmarks', 'Neighborhoods'],
#  'Nature & Wildlife Tours in San Francisco': ['Evergreen Escapes San Francisco'],
#  'Balmy Alley Murals': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Haight-Ashbury': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Neighborhoods',
#   'Historic Walking Areas'],
#  'Madame Tussauds San Francisco': ['Museums', 'Specialty Museums'],
#  'Room Escape Games in San Francisco': ['None'],
#  'Glide Memorial United Methodist Church': ['Sights & Landmarks',
#   'Sacred & Religious Sites'],
#  'Moscone Center': ['Traveler Resources', 'Conference & Convention Centers'],
#  'Transamerica Pyramid': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Union Square': ['Shopping', 'Shopping Malls'],
#  "Children's Creativity Museum": ['Museums', 'Specialty Museums'],
#  'San Francisco Public Library': ['Traveler Resources', 'Libraries'],
#  'Fort Mason Center': ['Nature & Parks', 'Museums', 'Marinas', 'Art Museums'],
#  'Painted Ladies': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Historic Sites'],
#  'The Coastal Trail': ['Outdoor Activities',
#   'Nature & Parks',
#   'Hiking Trails'],
#  'Photography Tours in San Francisco': ['Boutique Traveler'],
#  'Chinatown': ['Sights & Landmarks', 'Neighborhoods'],
#  'Japantown': ['Sights & Landmarks', 'Neighborhoods'],
#  'Washington Square': ['Nature & Parks',
#   'Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Fishing Charters & Tours in San Francisco': ['San Francisco Fishing Charter'],
#  'Seven Stills Brewery and Distillery': ['Food & Drink',
#   'Distilleries',
#   'Breweries'],
#  'The Beat Museum': ['Museums', 'Specialty Museums'],
#  'Fillmore Street': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'Bernal Heights': ['Sights & Landmarks', 'Neighborhoods'],
#  'Old Cathedral of St. Mary': ['Sights & Landmarks',
#   'Sacred & Religious Sites'],
#  'Grand View Park': ['Nature & Parks'],
#  'China Beach': ['Nature & Parks', 'Outdoor Activities', 'Beaches'],
#  'Aquatic Park': ['Sights & Landmarks', 'Nature & Parks', 'Neighborhoods'],
#  'Treasure Fest': ['Shopping', 'Flea & Street Markets'],
#  'Haas - Lilienthal House': ['Sights & Landmarks',
#   'Historic Sites',
#   'Architectural Buildings'],
#  'Louise M. Davies Symphony Hall': ['Concerts & Shows', 'Theaters'],
#  'Golden Gate Park Windmills & Tulips': ['Nature & Parks',
#   'Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Gardens'],
#  'War Memorial Opera House': ['Sights & Landmarks',
#   'Concerts & Shows',
#   'Theaters',
#   'Architectural Buildings'],
#  'Japan Center': ['Shopping',
#   'Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Shopping Malls'],
#  'Game & Entertainment Centers in San Francisco': ['None'],
#  'Haight Street': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  "San Francisco Maritime National Historical Park's Visitor Center": ['Museums',
#   'Specialty Museums'],
#  'St. Patrick Catholic Church': ['Sights & Landmarks',
#   'Churches & Cathedrals'],
#  'Martin Luther King, Jr. Memorial and Waterfall': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Bay Area Rapid Transit': ['Transportation', 'Mass Transportation Systems'],
#  'Civic Center': ['Sights & Landmarks', 'Civic Centers'],
#  'Clarion Alley Murals': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Stow Lake': ['Nature & Parks', 'Bodies of Water'],
#  'Greenwich Steps': ['Sights & Landmarks', 'Historic Walking Areas'],
#  'San Francisco Maritime Museum/Aquatic Park Bathhouse Building': ['Museums',
#   'Specialty Museums'],
#  'Hayes Valley': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Neighborhoods',
#   'Historic Walking Areas'],
#  'Dolphin & Whale Watching in San Francisco': ['None'],
#  'Spas in San Francisco': ['None'],
#  'Nordstrom': ['Shopping', 'Department Stores'],
#  'San Francisco Art Institute': ['Museums',
#   'Sights & Landmarks',
#   'Art Museums',
#   'Educational sites'],
#  'Market Street': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'Corona Heights': ['Nature & Parks'],
#  'Lafayette Park': ['Fun & Games', 'Nature & Parks', 'Playgrounds'],
#  "Dragon's Gate": ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'San Francisco Railway Museum': ['Museums', 'Specialty Museums'],
#  'Buena Vista Park': ['Nature & Parks', 'Sights & Landmarks', 'Lookouts'],
#  'Hidden Garden Steps': ['Nature & Parks',
#   'Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Gardens'],
#  'Autodesk Gallery': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'Running Tours in San Francisco': ['None'],
#  'Panhandle - Golden Gate Park': ['Nature & Parks'],
#  'Fort Mason, the Great Meadow': ['Sights & Landmarks',
#   'Nature & Parks',
#   'Military Bases & Facilities'],
#  'Contemporary Jewish Museum': ['Museums', 'Specialty Museums'],
#  'Angel Island Immigration Station': ['Sights & Landmarks',
#   'Historic Sites',
#   'Government Buildings'],
#  'San Francisco National Cemetery': ['Sights & Landmarks', 'Cemeteries'],
#  'The Bay Lights': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'Diego Rivera Mural': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'The National Shrine of Saint Francis of Assisi': ['Sights & Landmarks',
#   'Monuments & Statues',
#   'Sacred & Religious Sites'],
#  'Letterman Digital and New Media Arts Center': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Aquarium of the Bay': ['Zoos & Aquariums', 'Nature & Parks'],
#  'Sutro Heights Park': ['Nature & Parks'],
#  'Movie Theaters in San Francisco': ['None'],
#  'GLBT History Museum': ['Museums', 'Specialty Museums', 'History Museums'],
#  'Marina Green': ['Outdoor Activities',
#   'Nature & Parks',
#   'Jogging Paths & Tracks'],
#  'Steinhart Aquarium': ['Nature & Parks', 'Zoos & Aquariums'],
#  "Heart of the City Farmers' Market": ['Food & Drink',
#   'Shopping',
#   'Farmers Markets',
#   'Flea & Street Markets'],
#  "Women's Building Mural": ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Noe Valley': ['Sights & Landmarks', 'Neighborhoods'],
#  'San Francisco Visitor Information Center': ['Traveler Resources',
#   'Visitor Centers'],
#  'Embarcadero Center': ['Shopping',
#   'Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Shopping Malls'],
#  'Other Outdoor Activities in San Francisco': ['None'],
#  'Alta Plaza Park': ['Nature & Parks', 'Gardens'],
#  'Mount Davidson': ['Nature & Parks',
#   'Sights & Landmarks',
#   'Mountains',
#   'Sacred & Religious Sites'],
#  'The Fillmore': ['Concerts & Shows', 'Theaters'],
#  'National AIDS Memorial Grove': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Chinese Historical Society of America': ['Museums', 'History Museums'],
#  'Macy’s Union Square': ['Shopping', 'Department Stores'],
#  'Columbus Avenue': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'Off the Grid': ['Food & Drink', 'Other Food & Drink'],
#  'Cellarmaker Brewing Company': ['Food & Drink', 'Breweries'],
#  'San Francisco Bay Trail': ['Nature & Parks',
#   'Outdoor Activities',
#   'Hiking Trails'],
#  'Cartoon Art Museum': ['Museums', 'Art Museums', 'Specialty Museums'],
#  'Mrs Doubtfire House': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Pepper Palace': ['Food & Drink', 'Other Food & Drink'],
#  'Hotaling & Co.': ['Food & Drink', 'Distilleries'],
#  'Huntington Park': ['Nature & Parks'],
#  'Macondray Lane': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Historic Walking Areas'],
#  'Sentinel Building': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'Queen Anne Victorians': ['Sights & Landmarks', 'Architectural Buildings'],
#  "Levi's Plaza Park": ['Nature & Parks'],
#  'Other Fun & Games in San Francisco': ['None'],
#  "Cupid's Span": ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'Literary, Art & Music Tours in San Francisco': ['None'],
#  'Port of San Francisco': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Muni Forward': ['Transportation', 'Mass Transportation Systems'],
#  'Blues Clubs & Bars in San Francisco': ['None'],
#  'Marshall’s Beach': ['Outdoor Activities', 'Nature & Parks', 'Beaches'],
#  'Presidio Officers’ Club': ['Traveler Resources',
#   'Conference & Convention Centers'],
#  'Pier 24 Photography Museum': ['Museums', 'Specialty Museums'],
#  'Neiman-Marcus': ['Shopping', 'Department Stores'],
#  'Ripley s Believe It or Not! San Francisco': ['Museums', 'Specialty Museums'],
#  'Warfield Theater': ['Concerts & Shows', 'Theaters'],
#  'Museum of the African Diaspora': ['Museums',
#   'Specialty Museums',
#   'History Museums',
#   'Art Museums'],
#  'Camera Obscura': ['Sights & Landmarks',
#   'Museums',
#   'Points of Interest & Landmarks',
#   'Observatories & Planetariums'],
#  'American Conservatory Theater': ['Concerts & Shows', 'Theaters'],
#  'American Bookbinders Museum': ['Museums', 'Specialty Museums'],
#  'Portsmouth Square': ['Nature & Parks', 'Fun & Games', 'Playgrounds'],
#  'SHN Curran Theatre': ['Concerts & Shows', 'Theaters'],
#  'Ina Coolbrith Park': ['Nature & Parks'],
#  'Golf Courses in San Francisco': ['None'],
#  'Hendrik Point': ['Fun & Games', 'Nature & Parks', 'Playgrounds'],
#  'Xanadu Gallery (V. C. Morris Gift Shop)': ['Shopping',
#   'Museums',
#   'Art Galleries'],
#  'Full House House': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'Golden Gate Theatre': ['Concerts & Shows', 'Theaters'],
#  'Cow Hollow': ['Sights & Landmarks', 'Neighborhoods'],
#  'Bill Graham Civic Auditorium': ['Concerts & Shows', 'Theaters'],
#  'Hop-On Hop-Off Tours in San Francisco': ['Red and White Fleet'],
#  'Gay Clubs & Bars in San Francisco': ['None'],
#  'The Gregangelo Museum': ['Museums',
#   'History Museums',
#   "Children's Museums",
#   'Art Museums',
#   'Science Museums',
#   'Specialty Museums'],
#  'Tank Hill': ['Nature & Parks'],
#  'Black Hammer Brewing': ['Food & Drink', 'Breweries'],
#  'Embarcadero Center Cinema': ['Concerts & Shows', 'Theaters'],
#  'Local Brewing Co.': ['Food & Drink', 'Breweries'],
#  'Beach Chalet': ['Museums', 'Specialty Museums'],
#  'Transamerica Redwood Park': ['Nature & Parks'],
#  'Shakespeare Garden': ['Nature & Parks', 'Gardens'],
#  'BATS Improv': ['Concerts & Shows', 'Theaters'],
#  'SoMa': ['Sights & Landmarks', 'Neighborhoods'],
#  'Saks Fifth Avenue': ['Shopping', 'Department Stores'],
#  'Yerba Buena Center for the Arts': ['Concerts & Shows', 'Theaters'],
#  'Grateful Dead House': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Historic Sites'],
#  'Torpedo Wharf': ['Sights & Landmarks', 'Lookouts', 'Piers & Boardwalks'],
#  'Maison Bleu Maxime Le Forestier': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Don Edwards San Francisco Bay Wildlife Refuge': ['Nature & Parks',
#   'Nature & Wildlife Areas'],
#  'Battery Boutelle': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'Pioneer Monument': ['Sights & Landmarks', 'Monuments & Statues'],
#  'Stonestown Galleria': ['Shopping', 'Shopping Malls'],
#  'Lessons & Workshops in San Francisco': ['None'],
#  'The Wave Organ': ['Sights & Landmarks', 'Monuments & Statues'],
#  'Book Passage': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'San Francisco Flower Mart': ['Shopping', 'Flea & Street Markets'],
#  'The Flood Building': ['Sights & Landmarks', 'Historic Sites'],
#  'San Francisco Art Exchange': ['Museums',
#   'Shopping',
#   'Specialty Museums',
#   'Art Museums',
#   'Art Galleries'],
#  'Pioneer Park': ['Nature & Parks'],
#  'San Francisco Pride': ['Events', 'Cultural Events'],
#  'California Welcome Center': ['Traveler Resources', 'Visitor Centers'],
#  'Stockton Street': ['Sights & Landmarks', 'Neighborhoods'],
#  'Neptune Society Columbarium': ['Sights & Landmarks',
#   'Cemeteries',
#   'Architectural Buildings'],
#  'The Masonic': ['Concerts & Shows', 'Theaters'],
#  'Lake Merced': ['Nature & Parks', 'Bodies of Water'],
#  'Old United States Mint': ['Sights & Landmarks',
#   'Government Buildings',
#   'Architectural Buildings'],
#  'Comedy Clubs in San Francisco': ['None'],
#  'Strawberry Hill': ['Nature & Parks', 'Nature & Wildlife Areas'],
#  'Herbst Theatre': ['Concerts & Shows', 'Theaters'],
#  'The Strand Theater': ['Concerts & Shows', 'Theaters'],
#  'Multi-day Tours in San Francisco': ['Orange Sky Adventures'],
#  'Octagon House': ['Sights & Landmarks', 'Architectural Buildings'],
#  'Notre Dame Des Victoires Church': ['Sights & Landmarks',
#   'Churches & Cathedrals'],
#  'SF Armory': ['Sights & Landmarks', 'Historic Sites'],
#  'Ghost & Vampire Tours in San Francisco': ['None'],
#  'Press Club': ['Food & Drink', 'Wineries & Vineyards'],
#  'Speakeasy Ales & Lagers': ['Food & Drink', 'Breweries'],
#  'Crocker Galleria': ['Shopping', 'Shopping Malls'],
#  'Glad Tidings Church': ['Sights & Landmarks', 'Churches & Cathedrals'],
#  'Hardly Strictly Bluegrass Festival': ['Events', 'Music Festivals'],
#  'ZK Gallery': ['Museums', 'Shopping', 'Art Galleries'],
#  'Pacific Union Club': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'The Marsh': ['Concerts & Shows', 'Theaters'],
#  'USS San Francisco Memorial': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Sea Cliff': ['Sights & Landmarks', 'Neighborhoods'],
#  'Winery Collective': ['Food & Drink', 'Wineries & Vineyards'],
#  'Bluxome Street Winery': ['Food & Drink', 'Wineries & Vineyards'],
#  'Jack Early Park': ['Nature & Parks'],
#  'NFL Shop Pier 39': ['Shopping', 'Shopping Malls'],
#  'Mision San Francisco de Asis': ['Sights & Landmarks',
#   'Churches & Cathedrals'],
#  'The Color Factory': ['Museums', 'Art Museums'],
#  'California Historical Society': ['Traveler Resources',
#   'Museums',
#   'History Museums',
#   'Libraries'],
#  'Potrero Hill': ['Sights & Landmarks', 'Neighborhoods'],
#  "Lotta's Fountain": ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Fountains'],
#  'The Promenade': ['Sights & Landmarks', 'Historic Walking Areas'],
#  'Dance Clubs & Discos in San Francisco': ['None'],
#  'Yerba Buena Ice Skating & Bowling Center': ['Fun & Games',
#   'Sports Complexes'],
#  'Teuscher Chocolates of Switzerland': ['Food & Drink', 'Other Food & Drink'],
#  '450 Sutter Building': ['Sights & Landmarks', 'Architectural Buildings'],
#  'Victoria Theatre': ['Concerts & Shows', 'Theaters'],
#  'Vermont Street': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'Queen Wilhelmina Garden': ['Nature & Parks', 'Gardens'],
#  'Water World Swim': ['Outdoor Activities',
#   'Classes & Workshops',
#   'Sports Camps & Clinics'],
#  'Custom Made Theatre': ['Concerts & Shows', 'Theaters'],
#  'NextArts': ['Traveler Resources', 'Conference & Convention Centers'],
#  'Rodney Lough Jr. San Francisco Gallery': ['Museums',
#   'Shopping',
#   'Art Galleries'],
#  'Harvey Milk Plaza': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'Morrison Planetarium': ['Museums', 'Observatories & Planetariums'],
#  'Museum of Craft and Design': ['Museums', 'Specialty Museums'],
#  'Jack Kerouac Alley': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Maiden Lane': ['Sights & Landmarks', 'Historic Walking Areas'],
#  'Un-Scripted Theater Company': ['Concerts & Shows', 'Theaters'],
#  'San Francisco Water Taxi': ['Transportation', 'Ferries'],
#  'Esplanade': ['Nature & Parks'],
#  'Timbuk2 Factory Store': ['Shopping', 'Factory Outlets'],
#  'Martin Lawrence Galleries': ['Shopping', 'Museums', 'Art Galleries'],
#  "Bloomingdale's": ['Shopping', 'Department Stores'],
#  'San Francisco Zen Center': ['Sights & Landmarks',
#   'Sacred & Religious Sites'],
#  'Eden Fine Art': ['Shopping', 'Museums', 'Art Galleries'],
#  'Wine Bars in San Francisco': ['None'],
#  'Tenderloin Museum': ['Museums', 'History Museums'],
#  "St. Mary's Square": ['Fun & Games', 'Nature & Parks', 'Playgrounds'],
#  'Mohandas K. Gandhi (Gandhi Statue)': ['Sights & Landmarks',
#   'Monuments & Statues'],
#  'Salesforce Transit Center': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Mount Sutro Forest': ['Nature & Parks', 'Forests'],
#  'Glen Canyon Park': ['Nature & Parks'],
#  'Randall Museum': ['Museums', 'Science Museums', "Children's Museums"],
#  'Outside Lands': ['Events', 'Music Festivals'],
#  'Cooking Classes in San Francisco': ['None'],
#  "Mechanics' Institute Library and Chess Room": ['Sights & Landmarks',
#   'Traveler Resources',
#   'Points of Interest & Landmarks',
#   'Libraries',
#   'Architectural Buildings'],
#  '111 Minna Gallery': ['Museums', 'Shopping', 'Art Galleries'],
#  'Napier Lane': ['Sights & Landmarks', 'Historic Walking Areas'],
#  "Cliff's Variety": ['Shopping', 'Department Stores'],
#  'Franklin Bowles Gallery': ['Shopping', 'Museums', 'Art Galleries'],
#  'Upper Grant Avenue': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'South Park': ['Sights & Landmarks',
#   'Nature & Parks',
#   'Fun & Games',
#   'Playgrounds',
#   'Neighborhoods'],
#  'Moore Road Pier': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Piers & Boardwalks'],
#  'Holy Virgin Cathedral': ['Sights & Landmarks', 'Sacred & Religious Sites'],
#  'Holiday Ice Rink In Union Square': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Lyon Street': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Historic Walking Areas'],
#  'Sue Bierman Park': ['Nature & Parks'],
#  'Vinicola de Coppola': ['Food & Drink', 'Wineries & Vineyards'],
#  'St. Ignatius Church': ['Sights & Landmarks', 'Churches & Cathedrals'],
#  'Health/Fitness Clubs & Gyms in San Francisco': ['None'],
#  'Museo Italo Americano': ['Museums', 'Art Museums'],
#  'Tin How Temple': ['Sights & Landmarks', 'Sacred & Religious Sites'],
#  'International Art Museum of America': ['Museums', 'Art Museums'],
#  'Sacramento Street': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Neighborhoods'],
#  'Fay Park': ['Nature & Parks', 'Gardens'],
#  'Dolores Heights': ['Sights & Landmarks', 'Neighborhoods'],
#  'Raygun Gothic Rocketship (Pier 14)': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Marines Memorial Theater': ['Concerts & Shows', 'Theaters'],
#  'Holocaust Memorial at California Palace of the Legion of Hono': ['Sights & Landmarks',
#   'Monuments & Statues'],
#  'Yerba Buena Island': ['Nature & Parks', 'Islands'],
#  'St. Dominic Church': ['Sights & Landmarks', 'Churches & Cathedrals'],
#  'Billy Goat Hill Park': ['Sights & Landmarks', 'Nature & Parks', 'Lookouts'],
#  'Julius Kahn Playground': ['Fun & Games', 'Nature & Parks', 'Playgrounds'],
#  'Presidio Theatre': ['Concerts & Shows', 'Theaters'],
#  'Berggruen Gallery': ['Museums', 'Shopping', 'Art Galleries'],
#  'Kezar Stadium': ['Outdoor Activities', 'Jogging Paths & Tracks'],
#  'Swedenborgian Church': ['Sights & Landmarks', 'Sacred & Religious Sites'],
#  'Dennis Rae Fine Art': ['Museums', 'Shopping', 'Art Galleries'],
#  'The Jimi Hendrix House': ['Sights & Landmarks',
#   'Architectural Buildings',
#   'Points of Interest & Landmarks',
#   'Historic Sites'],
#  'Church of St. John Coltrane': ['Sights & Landmarks',
#   'Sacred & Religious Sites'],
#  'The Regency Ballroom': ['Sights & Landmarks', 'Civic Centers'],
#  'The Mechanics Monument': ['Sights & Landmarks', 'Monuments & Statues'],
#  '1.5-mile Coastal Trail': ['Outdoor Activities',
#   'Nature & Parks',
#   'Hiking Trails'],
#  'Jazz Clubs & Bars in San Francisco': ['None'],
#  'Walter S. Johnson Park': ['Nature & Parks'],
#  'John McLaren Park': ['Nature & Parks'],
#  'Sequoia Sake Company': ['Food & Drink', 'Breweries'],
#  'Circus Center': ['Concerts & Shows', 'Theaters'],
#  'Sydney Walton Square': ['Nature & Parks'],
#  'The Winery SF': ['Food & Drink', 'Wineries & Vineyards'],
#  "Admission's Day Statue": ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Monuments & Statues'],
#  'Treasure Island Wines': ['Food & Drink', 'Wineries & Vineyards'],
#  'Inspiration Point at the Presidio': ['Sights & Landmarks', 'Lookouts'],
#  'Nourse Theatre': ['Concerts & Shows', 'Theaters'],
#  '500 Capp Street Foundation': ['Museums',
#   'Shopping',
#   'Specialty Museums',
#   'Art Museums',
#   'Art Galleries'],
#  'Thread Lounge': ['Shopping', 'Antique Stores'],
#  '1AM Gallery': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'Alemany Flea Market': ['Shopping', 'Flea & Street Markets'],
#  'Jackson Square': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Neighborhoods'],
#  'Mission Bay Conference Center at UCSF': ['Traveler Resources',
#   'Conference & Convention Centers'],
#  'Cole Valley': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'Temple Emanu-El': ['Sights & Landmarks', 'Sacred & Religious Sites'],
#  'Letterform Archive': ['Traveler Resources',
#   'Museums',
#   'History Museums',
#   'Libraries'],
#  'Jefferson Airplane House': ['Sights & Landmarks', 'Historic Sites'],
#  'Comfort Women Statue - San Francisco': ['Museums', 'Specialty Museums'],
#  "Heron's Head Park": ['Nature & Parks', 'Nature & Wildlife Areas'],
#  'San Francisco Camerawork': ['Museums', 'Art Museums', 'Specialty Museums'],
#  'Spreckels Lake': ['Nature & Parks', 'Bodies of Water'],
#  'Images of the North': ['Museums', 'Shopping', 'Art Galleries'],
#  'Korean War Memorial': ['Sights & Landmarks',
#   'Monuments & Statues',
#   'Points of Interest & Landmarks'],
#  'Laughing Monk Brewing': ['Food & Drink', 'Breweries'],
#  'Justin Herman Plaza': ['Nature & Parks',
#   'Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Bay Area Ridge Trail': ['Nature & Parks',
#   'Outdoor Activities',
#   'Hiking Trails',
#   'Nature & Wildlife Areas'],
#  'Saint Boniface Catholic Church': ['Sights & Landmarks',
#   'Churches & Cathedrals'],
#  'Artillery Apparel Gallery': ['Museums', 'Shopping', 'Art Galleries'],
#  'Juan Bautista de Anza National Historic Trail': ['Nature & Parks',
#   'Outdoor Activities',
#   'Hiking Trails'],
#  'St. Mark’s Lutheran Church': ['Sights & Landmarks', 'Churches & Cathedrals'],
#  'San Francisco Brewing Company': ['Food & Drink', 'Breweries'],
#  'Cayuga Park': ['Fun & Games', 'Nature & Parks', 'Playgrounds'],
#  'Laurel Village Shopping Center': ['Shopping', 'Shopping Malls'],
#  'Richmond District': ['Sights & Landmarks', 'Neighborhoods'],
#  'Vulcan Steps': ['Sights & Landmarks', 'Historic Walking Areas'],
#  'Batteries to Bluffs trail': ['Nature & Parks',
#   'Outdoor Activities',
#   'Hiking Trails'],
#  'Language of the Birds': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Golden Gate overlook': ['Sights & Landmarks',
#   'Lookouts',
#   'Points of Interest & Landmarks'],
#  "Koret Children's Quarter": ['Fun & Games', 'Nature & Parks', 'Playgrounds'],
#  'Battery East Vista': ['Sights & Landmarks',
#   'Lookouts',
#   'Points of Interest & Landmarks'],
#  'Yoda fountain': ['Sights & Landmarks',
#   'Fountains',
#   'Monuments & Statues',
#   'Points of Interest & Landmarks'],
#  'Crab Sculpture': ['Sights & Landmarks',
#   'Monuments & Statues',
#   'Points of Interest & Landmarks'],
#  'Treecraft Distillery': ['Food & Drink', 'Distilleries'],
#  'Esmeralda Slide Park': ['Fun & Games', 'Nature & Parks', 'Playgrounds'],
#  'San Francisco Fire Dept Museum': ['Museums', 'Specialty Museums'],
#  'Music Concourse': ['Sights & Landmarks',
#   'Scenic Walking Areas',
#   'Points of Interest & Landmarks'],
#  'Ferment.Drink.Repeat - FDR Brwery': ['Food & Drink', 'Breweries'],
#  'Shannon Street Murals': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Bliss Dance Esculture': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Galeria de la Raza': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Gefen Fine Art': ['Museums', 'Shopping', 'Art Galleries'],
#  'Rocky Outcrop Park': ['Nature & Parks', 'Nature & Wildlife Areas'],
#  'The Gateway Theatre': ['Concerts & Shows', 'Theaters'],
#  'Caroline H. Hume Concert Hall': ['Concerts & Shows', 'Theaters'],
#  'Golden Gate Park Tennis Center': ['Fun & Games', 'Sports Complexes'],
#  "St. Luke' s Episcopal Church": ['Sights & Landmarks',
#   'Churches & Cathedrals'],
#  'San Francisco Columbarium': ['Sights & Landmarks',
#   'Scenic Walking Areas',
#   'Monuments & Statues',
#   'Cemeteries'],
#  'Eristavi Family Winery': ['Food & Drink', 'Wineries & Vineyards'],
#  'Red Poppy Art House': ['Museums', 'Shopping', 'Art Galleries'],
#  'Jefferson Square Park': ['Nature & Parks'],
#  'Congegration Sherith Israel': ['Sights & Landmarks',
#   'Churches & Cathedrals'],
#  'Missionary Temple Christian Methodist Episcopal Church': ['Sights & Landmarks',
#   'Churches & Cathedrals',
#   'Missions'],
#  "Andrea's Fountain": ['Sights & Landmarks',
#   'Fountains',
#   'Points of Interest & Landmarks'],
#  'Konko Church of San Francisco': ['Sights & Landmarks',
#   'Sacred & Religious Sites'],
#  'Sutro Tower': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Observation Decks & Towers'],
#  'Grand Central Station Antiques': ['Shopping', 'Antique Stores'],
#  'San Francisco Lesbian Gay Bisexual Transgender (LGBT) Community Center': ['Concerts & Shows',
#   'Theaters'],
#  'City Art': ['Shopping', 'Museums', 'Art Galleries'],
#  'Top of Broadway District': ['Sights & Landmarks', 'Scenic Walking Areas'],
#  'SF Art Market': ['Shopping', 'Flea & Street Markets'],
#  'Sigmund Stern Recreation Grove': ['Nature & Parks'],
#  'Candlestick Point State Recreation Area': ['Nature & Parks'],
#  'Clay Theater': ['Concerts & Shows', 'Theaters'],
#  'St. Matthews Lutheran Church': ['Sights & Landmarks',
#   'Churches & Cathedrals'],
#  'Kite Hill Open Space': ['Nature & Parks'],
#  'Museum of Vision': ['Museums', 'History Museums'],
#  'Velvet Da Vinci': ['Shopping', 'Museums', 'Art Galleries'],
#  'Cow Palace': ['Traveler Resources', 'Conference & Convention Centers'],
#  'Custom House': ['Sights & Landmarks',
#   'Historic Sites',
#   'Government Buildings',
#   'Architectural Buildings'],
#  'Spreckels Mansion': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Historic Sites'],
#  'Kiku Imports': ['Shopping', 'Antique Stores'],
#  'South Bay': ['Outdoor Activities',
#   'Nature & Parks',
#   'Sights & Landmarks',
#   'Bodies of Water',
#   'Scenic Drives'],
#  'Holy Trinity Greek Orthodox Church': ['Sights & Landmarks',
#   'Churches & Cathedrals'],
#  'Art for Children at the de Young Museum': ['Museums',
#   "Children's Museums",
#   'Art Museums'],
#  'Eureka Steam Ferry': ['Transportation', 'Ferries'],
#  'Arelious Walker Stairway': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Boxcar Theatre': ['Concerts & Shows', 'Theaters'],
#  'Terracotta Army Mural': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Square hearts': ['Sights & Landmarks', 'Monuments & Statues'],
#  'Farinelli Decorative Arts': ['Shopping', 'Antique Stores'],
#  'Corporate Goddesses': ['Sights & Landmarks',
#   'Monuments & Statues',
#   'Architectural Buildings',
#   'Points of Interest & Landmarks'],
#  'Civic Center Commons': ['Sights & Landmarks',
#   'Civic Centers',
#   'Points of Interest & Landmarks',
#   'Neighborhoods'],
#  '990 Fulton Street House': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'The Ordonez Gun': ['Sights & Landmarks', 'Monuments & Statues'],
#  'San Francisco Carousel': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Presidio Trust headquarters': ['Sights & Landmarks',
#   'Government Buildings',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Share Chairs': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'Guardians of the Gate': ['Sights & Landmarks', 'Monuments & Statues'],
#  'Pier 43 Ferry Arch': ['Sights & Landmarks',
#   'Monuments & Statues',
#   'Points of Interest & Landmarks'],
#  'Main Parade Ground': ['Nature & Parks'],
#  'Presidio Visitor Center': ['Traveler Resources', 'Visitor Centers'],
#  'Presidio Fire station': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings',
#   'Historic Sites'],
#  'Venus Statue,': ['Sights & Landmarks',
#   'Monuments & Statues',
#   'Points of Interest & Landmarks'],
#  'Bison Paddock': ['Nature & Parks', 'Nature & Wildlife Areas'],
#  'Hyde street pier': ['Sights & Landmarks',
#   'Piers & Boardwalks',
#   'Points of Interest & Landmarks'],
#  'Catharine Clark Gallery': ['Shopping', 'Museums', 'Art Galleries'],
#  'Golden Gate Heights Park': ['Fun & Games', 'Nature & Parks', 'Playgrounds'],
#  'Gordon Parks Centennial': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Alcazar Theatre': ['Concerts & Shows', 'Theaters'],
#  'WWII West Coast Memorial': ['Sights & Landmarks',
#   'Monuments & Statues',
#   'Points of Interest & Landmarks'],
#  'Russian Hill Park': ['Nature & Parks'],
#  'African American Art &Culture Complex': ['Museums', 'Specialty Museums'],
#  'The San Francisco Mead Company': ['Food & Drink',
#   'Wineries & Vineyards',
#   'Breweries'],
#  'Norras Temple': ['Sights & Landmarks', 'Sacred & Religious Sites'],
#  'Gagosian Gallery': ['Shopping', 'Museums', 'Art Galleries'],
#  'Pacific Heritage Museum of San Francisco': ['Museums',
#   'Specialty Museums',
#   'Art Museums'],
#  'Greater Farallones National Marine Sanctuary - Visitor Center': ['Traveler Resources',
#   'Visitor Centers'],
#  'Chloe Gallery': ['Museums', 'Shopping', 'Art Galleries'],
#  'Grand Pacheco Stairway': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Historic Walking Areas'],
#  'Presidio Pet Cemetery': ['Sights & Landmarks', 'Cemeteries'],
#  'Mission Creek Park': ['Nature & Parks'],
#  'Society of California Pioneers': ['Museums', 'History Museums'],
#  'Sanchez Street': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Historic Walking Areas'],
#  'The Mexican Museum': ['Museums', 'Specialty Museums', 'Art Museums'],
#  'Eurasian Interiors Chinese Antiques Furniture': ['Shopping',
#   'Antique Stores'],
#  'Forneris Farms': ['Sights & Landmarks', 'Farms'],
#  'SOMArts': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'Harry Steps': ['Sights & Landmarks', 'Historic Walking Areas'],
#  'Urban Dharma, Dharma Punx': ['Sights & Landmarks',
#   'Sacred & Religious Sites'],
#  'San Francisco History Room and Archives': ['Sights & Landmarks',
#   'Traveler Resources',
#   'Libraries',
#   'Civic Centers'],
#  'SFFD Fire Museum': ['Museums', 'Specialty Museums'],
#  'Kayaking & Canoeing in San Francisco': ['None'],
#  'Chinese United Methodist Church': ['Sights & Landmarks',
#   'Churches & Cathedrals',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Bay window': ['Sights & Landmarks',
#   'Observation Decks & Towers',
#   'Points of Interest & Landmarks'],
#  'Frank Cresci Plaza': ['Sights & Landmarks',
#   'Monuments & Statues',
#   'Points of Interest & Landmarks'],
#  'Pier 29': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Piers & Boardwalks'],
#  'Alvord Lake Bridge': ['Sights & Landmarks',
#   'Bridges',
#   'Points of Interest & Landmarks'],
#  'Archimedes': ['Sights & Landmarks', 'Monuments & Statues'],
#  'Buckyball': ['Sights & Landmarks',
#   'Monuments & Statues',
#   'Points of Interest & Landmarks'],
#  'Hermes and Dyonisus - Monument to Analysis': ['Sights & Landmarks',
#   'Monuments & Statues'],
#  'Light Cannons': ['Sights & Landmarks',
#   'Monuments & Statues',
#   'Points of Interest & Landmarks'],
#  'Dewey Monument': ['Sights & Landmarks',
#   'Monuments & Statues',
#   'Points of Interest & Landmarks'],
#  'First Public School': ['Sights & Landmarks', 'Historic Sites'],
#  'Square-Rigged Sailing Ship Balclutha': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Chapel of Our Lady': ['Sights & Landmarks',
#   'Churches & Cathedrals',
#   'Points of Interest & Landmarks'],
#  'Fort Mason chapel': ['Sights & Landmarks',
#   'Sacred & Religious Sites',
#   'Points of Interest & Landmarks'],
#  'Pier 31': ['Sights & Landmarks',
#   'Architectural Buildings',
#   'Points of Interest & Landmarks'],
#  'Eadweard Muybridge': ['Sights & Landmarks',
#   'Monuments & Statues',
#   'Points of Interest & Landmarks'],
#  'Philo T. Farnsworth statue': ['Sights & Landmarks', 'Monuments & Statues'],
#  'Lombard gates': ['Sights & Landmarks',
#   'Monuments & Statues',
#   'Points of Interest & Landmarks'],
#  'McLaren lodge': ['Sights & Landmarks',
#   'Architectural Buildings',
#   'Points of Interest & Landmarks'],
#  'Sharon building': ['Sights & Landmarks',
#   'Architectural Buildings',
#   'Points of Interest & Landmarks'],
#  'Pioneer log cabin': ['Sights & Landmarks',
#   'Architectural Buildings',
#   'Points of Interest & Landmarks',
#   'Historic Sites'],
#  'Presidio Chapel': ['Sights & Landmarks',
#   'Churches & Cathedrals',
#   'Sacred & Religious Sites',
#   'Points of Interest & Landmarks'],
#  'First Republic Bank': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings',
#   'Historic Sites'],
#  'Pershing square': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  "Banker's Heart": ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'Kong Chow Temple': ['Sights & Landmarks', 'Sacred & Religious Sites'],
#  'Upper Market': ['Sights & Landmarks', 'Neighborhoods'],
#  'San Francisco Performing Arts Library & Museum': ['Museums', 'Art Museums'],
#  'Gold Country': ['Outdoor Activities', 'Sights & Landmarks', 'Scenic Drives'],
#  'Motorcycle Tours in San Francisco': ['None'],
#  '49 Geary Street Art Galleries': ['Museums', 'Shopping', 'Art Galleries'],
#  'Museum of Ice Cream': ['Museums', 'History Museums'],
#  'TIX Bay Area': ['Traveler Resources', 'Visitor Centers'],
#  'Railways in San Francisco': ['None'],
#  'Gallery 444': ['Museums', 'Shopping', 'Art Galleries'],
#  'Sky Terrace': ['Sights & Landmarks', 'Observation Decks & Towers'],
#  "Francis Lefty O'Doul Bridge": ['Sights & Landmarks', 'Bridges'],
#  'Parasailing & Paragliding in San Francisco': ['None'],
#  'Vaillancourt Fountain': ['Sights & Landmarks', 'Fountains'],
#  'Distillery Tours in San Francisco': ['None'],
#  'San Francisco State University': ['Sights & Landmarks',
#   'Universities & Schools',
#   'Scenic Walking Areas'],
#  'Concerts in San Francisco': ['The Fillmore'],
#  'New United States Mint': ['Sights & Landmarks',
#   'Government Buildings',
#   'Architectural Buildings'],
#  'Adrenaline & Extreme Tours in San Francisco': ['None'],
#  'Karaoke Bars in San Francisco': ['None'],
#  'Yoga & Pilates in San Francisco': ['None'],
#  'Piano Bars in San Francisco': ['None'],
#  'Air Tours in San Francisco': ['None'],
#  'Pier 27': ['Sights & Landmarks',
#   'Piers & Boardwalks',
#   'Points of Interest & Landmarks'],
#  'Scuba & Snorkeling in San Francisco': ['None'],
#  'San Francisco Federal Building': ['Sights & Landmarks',
#   'Government Buildings'],
#  'Shopping Tours in San Francisco': ['None'],
#  'Cigar Bars in San Francisco': ['None'],
#  'Saturn Steps': ['Sights & Landmarks', 'Historic Walking Areas'],
#  'Love Lock Gate': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'Factory Tours in San Francisco': ['None'],
#  'Stand-Up Paddleboarding in San Francisco': ['None'],
#  'Waterskiing & Jetskiing in San Francisco': ['None'],
#  'Surfing, Windsurfing & Kitesurfing in San Francisco': ['None'],
#  'Water Sports in San Francisco': ['None'],
#  "Pacific Palisades Farmer's Market": ['Shopping',
#   'Food & Drink',
#   'Farmers Markets'],
#  '12 Gallagher Lane': ['Museums', 'Shopping', 'Art Galleries'],
#  'Ski & Snow Tours in San Francisco': ['None'],
#  'River Rafting & Tubing in San Francisco': ['None'],
#  'Defenestration Building': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Speed Boats Tours in San Francisco': ['None'],
#  'Boat Rentals in San Francisco': ['None'],
#  'Dinner Theaters in San Francisco': ['The Fillmore'],
#  'Safaris in San Francisco': ['None'],
#  'Coffee & Tea Tours in San Francisco': ['None'],
#  'Bus Transportation in San Francisco': ['None'],
#  'Gordon Biersch': ['Food & Drink', 'Breweries'],
#  '4WD, ATV & Off-Road Tours in San Francisco': ['None'],
#  'Scavenger Hunts in San Francisco': ['None'],
#  'Museum of Craft and Folk Art': ['Museums',
#   'Specialty Museums',
#   'Art Museums'],
#  'Mini Golf in San Francisco': ['None'],
#  'Fashion Shows & Tours in San Francisco': ['None'],
#  'Bowling Alleys in San Francisco': ['None'],
#  'Paint & Pottery Studios in San Francisco': ['None'],
#  'Vespa, Scooter & Moped Tours in San Francisco': ['None'],
#  'Grant Avenue': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'Bruce Lee mural': ['Sights & Landmarks',
#   'Scenic Walking Areas',
#   'Points of Interest & Landmarks'],
#  'Yerba Buena Island Vista Point': ['Sights & Landmarks',
#   'Scenic Walking Areas',
#   'Observation Decks & Towers',
#   'Points of Interest & Landmarks'],
#  'Jazz mural': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'Infantry row': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Historic Sites'],
#  'Boulder': ['Fun & Games',
#   'Nature & Parks',
#   'Playgrounds',
#   'Sports Complexes'],
#  'Dandelion': ['Sights & Landmarks',
#   'Monuments & Statues',
#   'Points of Interest & Landmarks'],
#  'Ghirardelli Building': ['Sights & Landmarks',
#   'Historic Sites',
#   'Points of Interest & Landmarks'],
#  'The Evolutionary Rainbow': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Robert Louis Stevenson Monument': ['Sights & Landmarks',
#   'Monuments & Statues'],
#  'Bowie/Lemmy/Prince Mural': ['Sights & Landmarks',
#   'Scenic Walking Areas',
#   'Points of Interest & Landmarks',
#   'Historic Sites'],
#  "America's Rock Stars Mural": ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Historic Sites'],
#  'High School of Commerce': ['Sights & Landmarks',
#   'Architectural Buildings',
#   'Points of Interest & Landmarks'],
#  'Pool of Enchantment': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'The Doughboy': ['Sights & Landmarks',
#   'Monuments & Statues',
#   'Points of Interest & Landmarks'],
#  'Pier One': ['Sights & Landmarks',
#   'Piers & Boardwalks',
#   'Points of Interest & Landmarks',
#   'Historic Sites'],
#  'Birthplace of Freemasonry': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Historic Sites'],
#  'Buich Building': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings',
#   'Historic Sites'],
#  'Bronze Sundial': ['Sights & Landmarks',
#   'Monuments & Statues',
#   'Points of Interest & Landmarks'],
#  'Borel and Company building': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Alvinza Hayward Building': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Lincoln Boulevard': ['Sights & Landmarks',
#   'Outdoor Activities',
#   'Scenic Drives'],
#  'Sing Fat Co. building': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings',
#   'Historic Sites'],
#  'Crown Zellerbach Building': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Golden Triangle Light Standards': ['Sights & Landmarks',
#   'Historic Walking Areas',
#   'Points of Interest & Landmarks'],
#  'Doolan-Larson Residence and Storefronts': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings',
#   'Historic Sites'],
#  'Flatiron Building': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Goodman Building': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Genella Building': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings',
#   'Historic Sites'],
#  'McMorry-Lagan Residence': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Mills Building and Mills Tower': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'First American Flag Raising in San Francisco': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Historic Sites'],
#  'Beltline Railroad Roundhouse': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Bauer & Schweitzer Malting Company building': ['Sights & Landmarks',
#   'Architectural Buildings',
#   'Historic Sites'],
#  "Archbishop's Mansion": ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Apple Cider Press statue': ['Sights & Landmarks', 'Monuments & Statues'],
#  'The barracks': ['Sights & Landmarks',
#   'Architectural Buildings',
#   'Points of Interest & Landmarks',
#   'Historic Sites'],
#  'Francis Scott Key Monument': ['Sights & Landmarks',
#   'Monuments & Statues',
#   'Points of Interest & Landmarks'],
#  'Russell Warren House': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Sarah Mish House': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'One Lombard Street': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings',
#   'Historic Sites'],
#  'Ulysses Simpson Grant Memorial': ['Sights & Landmarks',
#   'Monuments & Statues',
#   'Points of Interest & Landmarks'],
#  'Hibernia Bank building': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Don Lee Building': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Belli Building': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings',
#   'Historic Sites'],
#  'Bank of Italy building': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Columbus Savings Bank building': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'California Hall': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Bank of California building': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Phoebe Hearst Fountain': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Fountains',
#   'Monuments & Statues'],
#  'Spreckels Temple of Music': ['Sights & Landmarks',
#   'Architectural Buildings',
#   'Points of Interest & Landmarks'],
#  'Robin Williams Meadow': ['Nature & Parks', 'Gardens'],
#  'Poeme de la Vigne': ['Sights & Landmarks', 'Monuments & Statues'],
#  'The Verdi statue': ['Sights & Landmarks',
#   'Monuments & Statues',
#   'Points of Interest & Landmarks'],
#  'Golden Gate Park - Chinese Pavilion': ['Sights & Landmarks',
#   'Scenic Walking Areas',
#   'Points of Interest & Landmarks'],
#  'Samuels Clock': ['Sights & Landmarks',
#   'Monuments & Statues',
#   'Points of Interest & Landmarks',
#   'Historic Sites'],
#  'Federal Reserve Bank BUILDING': ['Sights & Landmarks',
#   'Government Buildings',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Haight-Ashbury Clock': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Peacock Meadow': ['Nature & Parks'],
#  'Fuchsia Dell': ['Nature & Parks', 'Gardens'],
#  'Dahlia Garden': ['Nature & Parks', 'Gardens'],
#  'Camellia Garden': ['Nature & Parks', 'Gardens'],
#  'Rose Garden': ['Nature & Parks', 'Gardens'],
#  'Joe DiMaggio Playground and North Beach Pool': ['Fun & Games',
#   'Nature & Parks',
#   'Playgrounds'],
#  'Marine Cemetery Vista': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Historic Sites'],
#  'Joseph Baermann Strauss statue': ['Sights & Landmarks',
#   'Monuments & Statues'],
#  'Federal Office Building': ['Sights & Landmarks',
#   'Government Buildings',
#   'Historic Sites'],
#  'Abraham Lincoln Monument': ['Sights & Landmarks',
#   'Monuments & Statues',
#   'Points of Interest & Landmarks'],
#  'Winding Stairway': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'CCBA building': ['Sights & Landmarks',
#   'Civic Centers',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Grove Street View': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Immigrant point overlook': ['Sights & Landmarks',
#   'Lookouts',
#   'Points of Interest & Landmarks'],
#  '575 Pierce Street House': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Pacific overlook': ['Sights & Landmarks',
#   'Lookouts',
#   'Points of Interest & Landmarks'],
#  'William Westerfeld House': ['Sights & Landmarks',
#   'Architectural Buildings',
#   'Points of Interest & Landmarks'],
#  'Henry Ohlhoff House': ['Sights & Landmarks',
#   'Architectural Buildings',
#   'Points of Interest & Landmarks'],
#  'Buena Vista Terrace': ['Sights & Landmarks',
#   'Architectural Buildings',
#   'Points of Interest & Landmarks'],
#  'Jerry Garcia Mural': ['Sights & Landmarks',
#   'Scenic Walking Areas',
#   'Points of Interest & Landmarks'],
#  '625 Scott Street House': ['Sights & Landmarks',
#   'Architectural Buildings',
#   'Points of Interest & Landmarks'],
#  'Civic Center Power House': ['Sights & Landmarks',
#   'Civic Centers',
#   'Architectural Buildings',
#   'Points of Interest & Landmarks'],
#  'UN Plaza Fountain': ['Sights & Landmarks',
#   'Fountains',
#   'Points of Interest & Landmarks'],
#  'United Nations Plaza': ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Ashurbanipal monument': ['Sights & Landmarks', 'Monuments & Statues'],
#  'Statua equeste Simon Bolivar': ['Sights & Landmarks', 'Monuments & Statues'],
#  'WWII Pacific War Memorial': ['Museums',
#   'History Museums',
#   'Military Museums'],
#  'Helen Diller Civic Center playground': ['Fun & Games',
#   'Nature & Parks',
#   'Playgrounds'],
#  "Tenderloin People's Garden Mural": ['Sights & Landmarks',
#   'Points of Interest & Landmarks'],
#  'Passage of remembrance': ['Sights & Landmarks', 'Monuments & Statues'],
#  'Veterans Building': ['Sights & Landmarks',
#   'Government Buildings',
#   'Points of Interest & Landmarks',
#   'Architectural Buildings'],
#  'Bond Latin Gallery': ['Museums', 'Shopping', 'Art Galleries'],
#  'Bay Jiu-Jitsu': ['Outdoor Activities',
#   'Classes & Workshops',
#   'Sports Camps & Clinics'],
#  'Romer Young Gallery': ['Shopping',
#   'Museums',
#   'Art Museums',
#   'Art Galleries'],
#  'Marrow Gallery': ['Museums', 'Shopping', 'Art Galleries'],
#  'Battery Chamberlin': ['Sights & Landmarks',
#   'Military Bases & Facilities',
#   'Points of Interest & Landmarks'],
#  'Book & Job Gallery': ['Shopping', 'Museums', 'Art Galleries'],
#  'Hall of Justice': ['Sights & Landmarks', 'Government Buildings'],
#  'Bass and Reiner': ['Shopping', 'Museums', 'Art Galleries'],
#  'J-Pop Summit': ['Events', 'Cultural Events'],
#  'Bank of Canton': ['Sights & Landmarks',
#   'Historic Sites',
#   'Points of Interest & Landmarks'],
#  'Victoria Manalo Draves Park': ['Nature & Parks',
#   'Fun & Games',
#   'Gardens',
#   'Playgrounds'],
#  'McKinley Square': ['Fun & Games', 'Nature & Parks', 'Playgrounds'],
#  '3 Fish Studios': ['Museums', 'Shopping', 'Art Galleries'],
#  'San Francisco Women Artists Gallery': ['Shopping',
#   'Museums',
#   'Art Galleries'],
#  'Vedanta Society of Northern California': ['Sights & Landmarks',
#   'Sacred & Religious Sites'],
#  'James R. Browning United States Courthouse': ['Sights & Landmarks',
#   'Points of Interest & Landmarks',
#   'Historic Sites'],
#  'AlSabeel Noor Al-Islam Mosque': ['Sights & Landmarks',
#   'Sacred & Religious Sites'],
#  'Art Attack SF': ['Shopping', 'Museums', 'Art Galleries'],
#  'Gallery 925': ['Sights & Landmarks', 'Points of Interest & Landmarks'],
#  'EXIT Theatre': ['Concerts & Shows', 'Theaters'],
#  'Stein Family Wines': ['Food & Drink', 'Wineries & Vineyards'],
#  'Mashouf Performing Arts Center': ['Concerts & Shows', 'Theaters'],
#  'Hua Zang Si': ['Sights & Landmarks', 'Sacred & Religious Sites'],
#  'BAPS Shri Swaminarayan Mandir': ['Sights & Landmarks',
#   'Churches & Cathedrals'],
#  'Fouladi Projects': ['Museums', 'Shopping', 'Art Galleries'],
#  'The Distilled Man': ['Sights & Landmarks', 'Educational sites'],
#  "ABC's '7Live' Voice Box": ['Concerts & Shows', 'Theaters'],
#  'Concourse Exhibition Center': ['Traveler Resources',
#   'Conference & Convention Centers'],
#  'Intersection for the Arts': ['Museums', 'Art Museums'],
#  'Labyrinth of Cultures': ['Museums', 'Specialty Museums'],
#  'Phoenix Gallery': ['Shopping', 'Museums', 'Art Galleries'],
#  "Buddha's Universal Church": ['Sights & Landmarks',
#   'Sacred & Religious Sites'],
#  'San Francisco African American Historical & Cultural Society': ['Museums',
#   'Specialty Museums',
#   'History Museums'],
#  'Allyne Park': ['Nature & Parks'],
#  'Meyerovich Gallery': ['Shopping', 'Museums', 'Art Galleries'],
#  'Maxwell Galleries': ['Museums', 'Shopping', 'Art Galleries'],
#  'Hang': ['Shopping', 'Museums', 'Art Galleries'],
#  'Fraenkel Gallery': ['Shopping', 'Museums', 'Art Galleries'],
#  'Eleonore Austerer Gallery': ['Shopping', 'Museums', 'Art Galleries'],
#  'Atelier Dore': ['Shopping', 'Museums', 'Art Galleries'],
#  'Russian Center of San Francisco': ['Museums',
#   'Specialty Museums',
#   'History Museums'],
#  '381 G Gallery': ['Museums', 'Shopping', 'Art Galleries'],
#  'Gallery of Ethnic Art': ['Shopping', 'Museums', 'Art Galleries'],
#  'Upper Fillmore': ['Sights & Landmarks', 'Neighborhoods'],
#  'Bullock and Jones': ['Shopping', 'Department Stores'],
#  'Wolf Ridge Loop': ['Nature & Parks',
#   'Outdoor Activities',
#   'Hiking Trails',
#   'Jogging Paths & Tracks'],
#  'McLellan Botanicals': ['Nature & Parks', 'Gardens'],
#  'Telephone Pioneers Communication Museum': ['Museums',
#   'Specialty Museums',
#   'History Museums'],
#  'Ecology Trail': ['Nature & Parks', 'Outdoor Activities', 'Hiking Trails'],
#  'Redwood Empire Association': ['Traveler Resources', 'Visitor Centers']}

# %%
# for user1
def make_profiles_new(matrix,loc_info_clean):
    profiles={}
    for u in range(len(matrix)):
        features_list=[]
        for i in range(len(matrix[0])):
            try:
                features_list+=int(matrix[u][i])*(loc_info_clean[places[i][15:]])
            except:
                pass

        new_features=[]
        for f in features_list:
            try:
                nf=style_mapper_v2[f]
                if type(nf)==str:
                    new_features.append(nf)
                else:
                    new_features+=nf
            except:
                pass

        ct=Counter(new_features)
        tot=sum(ct.values())

        #res={k:10*ct[k]/tot for k in ct.keys()}
        res={k:ct[k] for k in ct.keys()}
        profiles[u]=res
    return profiles

# %%
new_profiles=make_profiles_new(matrix,loc_info_clean)

# %%
new_np_profiles=convert_profile_to_np(new_profiles)

# %%
style_mapper_v2[features_list[34]]
# Out:
# 'Nature'

# %%
new_features=[]
for f in features_list:
    try:
        nf=style_mapper_v2[f]
        if type(nf)==str:
            new_features.append(nf)
        else:
            new_features+=nf
    except:
        pass

# %%
sum(Counter(new_features).values())
# Out:
# 89

# %%
def make_profiles_new(matrix,ta_features_dct):
    profiles={}
    for u in range(len(matrix)):
        st=''
        for i in range(len(matrix[0])):
            st+=int(matrix[u][i])*(ta_feature_dct[places[i][15:]]+' ').replace(' & ','+').replace('Must See','Must-See')
        res1=Counter(flatten([style_mapper[x.strip(',')] for x in st.split()]))
        keys=res1.keys()
        #res1p={k:10*res1[k]/sum([res1[k] for k in keys]) for k in keys}
        res1p={k:res1[k] for k in keys}
        profiles[u]=res1p
    return profiles

# %%
user_visited_places=[]
for u in res.keys():
    for place in res[u].keys():
        place_minus_sf=place[15:]
        user_visited_places.append(place_minus_sf)

# %%
uvp_set=set(user_visited_places)

# %%
def make_labeled_uvp(uvp_set,labeled_locations):
    labeled_uvp={}
    for pc in uvp_set:
        comp_best=0
        current_closest=None
        for sft in labeled_locations:
            comp=fuzz.ratio(pc.lower().replace('san francisco',' '),sft.lower().replace('san francisco',' '))
            if comp>comp_best:
                comp_best=comp
                current_closest=sft

        if comp_best>83:
            labeled_uvp[pc]=current_closest
    return labeled_uvp

# %%
labeled_uvp=make_labeled_uvp(uvp_set,list(loc_info.keys()))

# %%
attraction_types=[]
for x in loc_info.keys():
    attractions=loc_info[x][1]
    attraction_types+=attractions

# %%
style_mapper_v2={'Dandyhorse San Francisco Bike Tours & Rental':['Life','Nature'],'Concerts & Shows':'Life',\
                 'Events':'Life','Evergreen Escapes San Francisco':'Nature','Food & Drink':'Life',\
                'Fun & Games':'Life','Magic Bus':'Life','Museums':'Culture','Nature & Parks':'Nature',\
                 'Outdoor Activities':'Nature','Streets of San Francisco Bike Tours':['Nature','Life'],\
                 'Shopping':'Life','Sights & Landmarks':'History','The Fillmore':['History','Life','Culture'],\
                 'Zoos & Aquariums':'Nature','Bridges':'History','Music Festivals':['Culture','Life'],\
                'Antique Stores':['Culture','History'],'State Parks':'Nature','Symphonies':'Culture',\
                 'History Museums':'History','Architectural Buildings':['History','Culture'],'Ferries':['Nature','Life'],\
                'Other Food & Drink':'Life','Mountains':'Nature','Fountains':'Nature','Lighthouses':['History','Nature'],\
                'Art Galleries':'Culture','Children\'s Museums':'Culture','Art Museums':'Culture',\
                'Historic Sites':'History','Hiking Trails':'Nature','Bodies of Water':'Nature',\
                 'Farmers Markets':['Life','Culture'],'Sports Camps & Clinics':'Life','Ships':'History',\
                'Cultural Events':'Culture','Events':'Life','Neighborhoods':['Life','Culture'],\
                'Military Bases & Facilities':'History','Observatories & Planetariums':'Culture',\
                'Government Buildings':'History','Factory Outlets':'Life','Military Museums':['History','Culture'],\
                'Shopping Malls':'Life','Conference & Convention Centers':'Life','Specialty Museums':'Culture',\
                'Scenic Walking Areas':'Nature','Historic Walking Areas':'Nature','Jogging Paths & Tracks':'Nature',\
                'Lookouts':'Nature','Marinas':'Nature','Sports Complexes':'Life','Monuments & Statues':'History',\
                'Missions':'History','National Parks':'Nature','Nature & Wildlife Areas':'Nature','Beaches':'Nature',\
                'Piers & Boardwalks':'Nature','Science Museums':'Culture','Arenas & Stadiums':'Life',\
                'Scenic Drives':['Life','Nature'],'Department Stores':'Life','Wineries & Vineyards':['Culture','Nature','Life'],\
                'Department Stores':'Life','Cemeteries':['History','Culture','Nature'],'Points of Interest & Landmarks':['History','Culture'],\
                'Theaters':['Culture','Life'],'Islands':'Nature','Forests':'Nature','Distilleries':'Life','Breweries':'Life',\
                'Operas':'Culture','Ballets':'Culture','Churches & Cathedrals':['History','Culture'],\
                 'Sacred & Religious Sites':['History','Culture'],'Gardens':'Nature','Libraries':['Life','Culture'],\
                'Universities & Schools':['History','Culture'],'Farms':'Nature','Classes & Workshops':'Life',\
                'Observation Decks & Towers':'Nature',"Outspoke'n Bike Rentals":['Life','Nature'],'Tramways':['Culture','History']}

# %%
[x for x in set(new_at) if x not in sorted(set(style_mapper_v2.keys()))]
# Out:
# ['Mass Transportation Systems',
#  'Educational sites',
#  'Bay Voyager',
#  'Playgrounds',
#  'Vantigo Tours',
#  'City Segway Tours San Francisco',
#  'San Francisco Fishing Charter',
#  'Flea & Street Markets',
#  'Civic Centers',
#  'Orange Sky Adventures',
#  'Transportation',
#  'Boutique Traveler',
#  'Red and White Fleet',
#  'Xela Imports',
#  'Traveler Resources',
#  'Visitor Centers',
#  'None',
#  'San Francisco Native Tours']

# %%
at=set(attraction_types)
new_at=[x for x in at if 'Reviews' not in x]

# %%
# make_matrix takes in a list of rankings of attractions as well as a dictionary (site to labels) and spits out 
# 1) an array of user preferences, 2) a list of users and 3) a list of attractions.  The only reason we need to feed
# in the dictionary is to see if there is labeled data....

def make_matrix(users,ta_to_sf):
    user_list=list(users.keys())
    places=[]
    for user_key in users.keys():
        for place in users[user_key].keys():
            place_minus_sf=place[15:]
            if place_minus_sf in list(ta_to_sf.keys()):
                places.append(place)
    places=list(set(places))


    matrix=[]
    for u in user_list:
        user_likes=[]
        for p in places:
            if p in users[u].keys():
                user_likes.append(users[u][p])
            else:
                user_likes.append(float('NaN'))
        matrix.append(user_likes)

    return np.array(matrix), user_list, places


# get_data takes in the results 'res' above and spits out a 'clean' matrix of user preferences
# as well as a list of users and places.  This is basically a cleaned version of 'make_matrix'

def get_data(res,ta_to_sf):
    
    matrix, user_list, places = make_matrix(res,ta_to_sf)
    
    good_list=[]
    for i in range(len(matrix)):
        if sum(np.nan_to_num(matrix[i],0))!=0:
            good_list.append(i)
            
    users_clean=np.array(user_list)[good_list]
    matrix_clean=matrix[good_list]
    return matrix_clean, users_clean, places

# make profiles creates a user profile based on past data and the labels for each site that were scraped from 
# sf_trip

def make_profiles(matrix,ta_features_dct):
    profiles={}
    for u in range(len(matrix)):
        st=''
        for i in range(len(matrix[0])):
            st+=int(matrix[u][i])*(ta_feature_dct[places[i][15:]]+' ').replace(' & ','+').replace('Must See','Must-See')
        res1=Counter(flatten([style_mapper[x.strip(',')] for x in st.split()]))
        keys=res1.keys()
        res1p={k:10*res1[k]/sum([res1[k] for k in keys]) for k in keys}
        profiles[u]=res1p
    return profiles

#Now we convert the profiles to numpy.

def convert_profile_to_np(profiles,attributes=['Nature','History','Culture','Life']):
    np_profiles=[]
    for u in range(len(matrix)):
        user_profile=[]
        for a in attributes:
            if a in profiles[u].keys():
                user_profile.append(profiles[u][a])
            else:
                user_profile.append(0)
        np_profiles.append(user_profile)
    return np.array(np_profiles)

#Flatten is just a helper function for 'make_profiles'

def flatten(testlist):
    acc=[]
    for x in testlist:
        if type(x)==str:
            acc.append(x)
        elif type(x)==list:
            acc+=x
    return acc

# This is just a wrapper for creating the recsys class.  The wrapper allows us to automatically initialize
# the number of users and attractions

def create_recsys(matrix,dropout=.1,latent_features=4,max_iter=100,lr=.001,epochs=5,temperature=1,batch_size=500):
    return recsys(matrix,matrix.shape[0],matrix.shape[1],latent_features,dropout,max_iter,epochs,temperature,lr,\
                 batch_size=batch_size)


style_mapper={'Adventure':'Nature', 'Art':'Culture','Cuisine':'Life','Culture':'Culture',\
              'Fun+Entertainment':['Life','History'],'History':'History','Landmark':'History','Museum':'Culture',\
              'Must-See':'History','Nature':'Nature','Nightlife':'Life','Shopping':'Life','Sports':'Life',\
              'Tour':'Life','R+R':'Life'}

# %% [markdown]
# ## Building and Training Model
#
# ### Now that we have the code above it is simple to train a model.

# %%
matrix, users, places = get_data(res,ta_to_sf)

# %%
profiles=make_profiles(matrix,ta_feature_dct)

np_profiles=convert_profile_to_np(profiles)

# %%
plt.hist(testsum,bins=1000)
plt.xlim(0,.04)
plt.show()

# %% [markdown]
# In the next line we make a new array which combines the generated user profiles with their historical data.

# %%
new_matrix=np.concatenate((new_np_profiles,matrix),axis=1)

# %% [markdown]
# Now we want to train a model on our data.  Since the training is going to take a long time let's just look at a small sample to see if things are working.  I'll pick 500 users randomly just to get started. I'll also initialized a recsys using the create_recsys function above.

# %%
#sample=np.random.choice(range(len(new_matrix)),50,replace=False)
test_real=create_recsys(new_matrix,max_iter=100,lr=.01,epochs=10,batch_size=500,latent_features=10)

# %%
#Let's compute the average and std rating for each site.

full_predictions=test_real.predict(new_matrix)
full_predictions2=full_predictions[:,4:].detach().numpy()
averages=[np.mean(full_predictions2[:,i]) for i in range(len(places))]
stds=[np.std(full_predictions2[:,i]) for i in range(len(places))]

# %%
test_real.fit()
# Out:
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Epoch 10

# %% [markdown]
# Now we have a fit model.  Let's suppose a new user comes along with no previous history.  We will ask him to fill out fill out a questionaire describing his/her preference for ['Nature','History','Culture','Life'], in that order.

# %%
preferences=[1,1000000,10,0]

# This user really likes nature, sort of likes culture, but is ambivalent about history and 'life'.
# Note that the internally the scores are normalized such that the sum is 10, hence the extra factors below. 

new_user_preferences=(10/sum(preferences))*np.array(preferences)

#Since we know nothing about the new user we just initialize their site rankings to zero. 

initialization=np.zeros(len(matrix[0]))

#Finally, we combine the preferences with the initialization to represent the new user as a row.

new_user=np.concatenate((new_user_preferences,initialization),axis=0)


#Let's figure out what the user likes!
predictions_raw=test_real.predict(new_user)

# These are raw predictions.  We want to filter out the 'background effect'.  To do this we subtract off the average preferences.

predictions_shifted=predictions_raw[4:].detach().numpy()-np.array(averages)
predictions=sorted(list(enumerate([predictions_shifted[i]/stds[i] for i in range(len(predictions_shifted))])),\
                   key=lambda x: x[1],reverse=True)

# %%
#Let's figure out what the user likes!
#predictions=sorted(list(enumerate(test_real.predict(new_user))),key=lambda x: x[1],reverse=True)
sites=[[places[p[0]][15:],float(p[1])] for p in predictions[:20]]
sites
# Out:
# [['Golden Gate Bridge', 7.277243614196777],
#  ['Alcatraz Cruises, LLC', 6.863089084625244],
#  ['The Waterfront Bakery', 6.728348731994629],
#  ['Gialina Pizzeria', 6.655496597290039],
#  ['Bix', 6.563409328460693],
#  ['Salt & Straw', 6.24951171875],
#  ['Nordstrom', 6.1594953536987305],
#  ['Cable Cars', 5.832560062408447],
#  ['Coit Tower', 5.4632344245910645],
#  ['Telegraph Hill', 5.420362949371338],
#  ['San Francisco Love Tour', 5.39027738571167],
#  ["Tad's Steakhouse", 5.3486647605896],
#  ['Saigon Sandwich Shop', 5.343319416046143],
#  ["Pedro's Cantina", 5.328435897827148],
#  ['Great American Music Hall', 4.936143398284912],
#  ['Golden Boy Pizza', 4.900278091430664],
#  ['Dumpling Time', 4.692088603973389],
#  ['Sightglass Coffee', 4.628865718841553],
#  ['San Francisco Helicopter and Alcatraz Tour', 4.570711135864258],
#  ['Crystal Jade Jiang Nan', 4.534503936767578]]

# %%
raw_pred=sorted(list(enumerate(predictions_raw.detach().numpy())),key=lambda x:x[1],reverse=True)
[places[p[0]][15:] for p in raw_pred[:30]]
# Out:
# ['The House',
#  'Alcatraz Island',
#  'Katana-ya',
#  'Sheba Piano Lounge',
#  'Kabuki Springs and Spa',
#  'Burger Bar',
#  'El Techo',
#  "Fishermen's Grotto",
#  'Redwood Ramblers',
#  "Tommy's Mexican Restaurant",
#  'Waterfront Restaurant and Cafe',
#  'Golden Gate Bridge',
#  'San Francisco Helicopter and Alcatraz Tour',
#  'Hog Island Oyster Company',
#  'Urban Putt',
#  'The Boardroom',
#  "Mama's on Washington Square",
#  'Golden Boy Pizza',
#  'MaSo',
#  'Blazing Saddles Bike Rentals and Tours',
#  'Crab House at Pier 39',
#  'City Sightseeing',
#  'Cotogna',
#  'Caffe Baonecci',
#  'Hana Zen Sushi Bar - Pier 39',
#  'The Plant Cafe Organic',
#  'Rosamunde Sausage Grill',
#  'San Francisco Fire Engine Tours & Adventures',
#  'Monsieur Benjamin',
#  'The Stinking Rose - San Francisco']

# %%
plt.scatter(list(range(len(test_real.losses))),test_real.losses,s=.1)
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.ylim(0,1)
plt.show()

# %% [markdown]
# ## Notes:
#
# The results are not very representative of the user profile.  One might hope that if we set the user profile to 'nature=10, else=0', we would only get outdoors activities.  The problems is that everything is filtered through a neuro network which is influenced by what the 'nature-lovers' and others actually did in the past.....  These past actions are not necessarily in alignment with the ratings....
#
# Let's imagine a simpler world where any user who likes nature ONLY visits natural attractions... I.e., there is a strong correlation between the labels and what one actually does.  In this world, we should be able to pick out purely 'natural' activies....
#
# Need to transform rankings to something like "10(site_score_for_user - avg_site_score)"
#
# Also, are we really masking unseen data???
